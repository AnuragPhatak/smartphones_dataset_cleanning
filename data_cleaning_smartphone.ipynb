# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('smartphones.csv')

# %%
data = df.copy()

# %%
data.head()

# %% [markdown]
# ### column(model)

# %%
## column(model): unnecessary information in model like (5gb,128gb)
data['model'] = data['model'].str.replace('5G','')
data ['model'] = data['model'].str.split('(').str[0].str.strip()

# %%
## extract brand name
data.insert(1,'brand_name',data['model'].str.split(' ').str[0])

# %% [markdown]
# ## column(price)

# %%
## remove comma and ruppes symbol
data['price'] = data['price'].str.replace(',','').str.replace('₹','')

# %% [markdown]
# ## column(rating)

# %%
## The skewness is -0.699, which indicates that the distribution of the ratings is slightly negatively skewed. it is
## better to fill null values with median

# %%
data['rating'].isnull().sum()

# %%
data['rating'].describe()

# %%
sns.distplot(data['rating'], kde=True)

# %%
data['rating'] = data['rating'].fillna(data['rating'].median())

# %% [markdown]
# ## column(sim)

# %%
## create three more columns -- 5g,nfc,ir_blaster
data['has_5g'] = data['sim'].str.contains('5G', case=False)
data['has_ir_blaster'] = data['sim'].str.contains('IR Blaster',case=False)

# %% [markdown]
# ## column(processor)

# %%
## create two new columns [processor_name , num_of_cores]
data['num_of_core'] = data['processor'].str.extract(r'(\b\w+\s+Core\b)')[0]

# %%
processor_names = data['processor_name'].unique()
unique_processor_names = []

for i in processor_names:
    new = i.split(' ')[0] 
    if new not in unique_processor_names: 
        unique_processor_names.append(new)  
unique_processor_names
processor_brands = ['Snapdragon', 'Exynos', 'Dimensity', 'Bionic', 'Helio', 'Kirin', 'Unisoc', 'Apple', 'MediaTek', 'Qualcomm','Google']

# %%
import numpy as np
def process_brand(processor_name):
    for brand in processor_brands:
        if brand in processor_name:
            return brand
    return np.nan
data['processor_brand'] = data['processor'].apply(process_brand)
data[['processor', 'processor_brand']].head()

# %%
data['processor_brand'].unique()

# %%
data['num_of_core'].unique()

# %% [markdown]
# ## column(ram)

# %%
## create two more columns(ram_capacity,space)

# %%
unique_rams = []
for i in data.ram:
    ram = i.replace('\u2009', ' ')
    result = ram.split(' ')[0]
    try:
        ram_value = int(result)
        if ram_value < 15 and ram_value not in unique_rams:
            unique_rams.append(ram_value)
    except ValueError:
        continue 
unique_rams

# %%
def ram_cap(ram):
    for i in unique_rams:
        if str(i) in ram:
            return i
    return np.nan
data['ram_capacity'] = data['ram'].apply(ram_cap)

# %%
data['ram_capacity'].head()

# %%
unique_storage = []
for i in data.ram:
    storage = i.replace('\u2009', ' ')
    result = storage.split(',')
    for item in result:
        item = item.strip()
        try:
            storage_value = int(item.split(' ')[0]) 
            if storage_value < 600:  
                unique_storage.append(storage_value)
        except ValueError:
            continue  
unique_storage = list(set(unique_storage)) 
unique_storage

# %%
def uni_storage(storage):
    for i in unique_storage:
        if str(i) in storage:
            return i
    else:
        return np.nan
data['storage_capacity'] = data['ram'].apply(uni_storage)

# %%
data['storage_capacity'].unique()

# %% [markdown]
# ### column(battery)

# %%
battery = []
for i in data.battery:
    mah = i.replace('\u2009', ' ')
    try:
        res = int(mah.split(' ')[0])
        if res > 1000:
            battery.append(res)
    except ValueError:
            continue  
battery = list(set(battery))
battery

# %%
def mah_cap(bat):
    for i in battery:
        if str(i) in bat:
            return i
    else:
        return np.nan
data['mah_capacity'] = data['battery'].apply(mah_cap)

# %% [markdown]
# ## column(display)

# %%
## add new columns screen_size and resolution
li = []
for i in data.display:
    res = i.split(' ')[0]
    try :
        if float(res) < 10:
            li.append(res)
    except ValueError:
            continue

# %%
def screen(screen):
    for i in li:
        if str(i) in screen:
            return i
    else:
        return np.nan
data['screen_size'] = data['display'].apply(screen)

# %%
# resolution column
resolution =  []
for i in data.display:
    i = i.replace('\u2009', ' ').strip()
    try:
        split = i.split(',')[1].strip()
        if 'x' in split:
            px_pos = split.find('px')
            resolution.append(split[:px_pos].strip())
        else:
            continue
    except IndexError:
        continue
resolution = list(set(resolution))

# %%
def screen_res(res):
    res = res.replace('\u2009', ' ').strip()  
    for i in resolution:
        if i in res:
            return i
    return np.nan
data['screen_reosolution'] = data['display'].apply(lambda x: screen_res(x))
data[['display', 'screen_reosolution']]

# %% [markdown]
# ## camera

# %%
def extract_rear_camera(camera_str):
    if isinstance(camera_str, str):
        cleaned_str = camera_str.replace('\u2009', ' ')
        pos = cleaned_str.find('&')
        if pos != -1:
            return cleaned_str[:pos].strip()
        else:
            return cleaned_str.strip()
    else:
        return None

data['rear_camera'] = data['camera'].apply(extract_rear_camera)
data.head()

# %%
def front_camera(front_str):
    if isinstance(front_str,str):
        cleaned_str = front_str.replace('\u2009', ' ')
        pos = cleaned_str.find('&')
        if pos != -1:
            return cleaned_str[pos:]
        else:
            return None
    else:
        pass
data['front_camera'] = data['camera'].apply(front_camera)
data['front_camera'] = data['front_camera'].str.replace('& ','')
data['front_camera'] = data['front_camera'].str.replace('MP Front Camera','')

# %% [markdown]
# ## card column

# %%
def card_support(card):
    if isinstance(card, str):
        if 'Memory Card Supported' in card:
            return True
        else:
            return False
    else:
        return False
data['memory_card_supported'] = data['card'].apply(card_support)

# %% [markdown]
# ##  dropping columns

# %%
data = data.drop(columns=['battery', 'camera', 'ram', 'display', 'processor', 'sim'])

# %%
data = data.drop(columns='card')

# %% [markdown]
# ## camera column

# %%
data['rear_camera'] = data['rear_camera'].str.replace('MP Triple Rear','').str.replace('MP ','')

# %%
data['rear_camera'] = data['rear_camera'].str.replace('Quad Rear','').str.replace('Dual Rear','').str.replace('Rear','')

# %%
data.head(10)

# %% [markdown]
# ### rearanging the columns

# %%
columns = data.columns.to_list()
order = ['model','brand_name','price','rating','has_5g','has_ir_blaster','os','processor_name','processor_brand'
        ,'num_of_core','ram_capacity','storage_capacity','mah_capacity','screen_size','screen_reosolution','rear_camera',
        'front_camera','memory_card_supported']
data = data[order]

# %% [markdown]
# ## os column

# %%
def os_name(name):
    if isinstance(name, str): 
        if 'Android' in name:
            return 'android'
        elif 'iOS' in name:
            return 'ios'
        elif 'Not Specified' in name:
            return name
        elif 'Harmony' in name or 'Hongmeng' in name:
            return 'other'
        else:
            return np.nan
    else:
        return np.nan  
data['os'] = data['os'].apply(os_name)

# %%
data.head(20)
# Out:
#                             model brand_name   price  rating  has_5g  \
# 0                      OnePlus 11    OnePlus   54999    89.0    True
# 1          OnePlus Nord CE 2 Lite    OnePlus   19989    81.0    True
# 2              Samsung Galaxy A14    Samsung   16499    75.0    True
# 3               Motorola Moto G62   Motorola   14999    81.0    True
# 4              Realme 10 Pro Plus     Realme   24999    82.0    True
# 5              Samsung Galaxy F23    Samsung   16999    80.0    True
# 6                 Apple iPhone 14      Apple   65999    81.0    True
# 7   Xiaomi Redmi Note 12 Pro Plus     Xiaomi   29999    86.0    True
# 8                 Nothing Phone 1    Nothing   26749    85.0    True
# 9                 OnePlus Nord 2T    OnePlus   28999    84.0    True
# 10                  Realme 10 Pro     Realme   18999    82.0    True
# 11                       Oppo A78       Oppo   18999    79.0    True
# 12       Xiaomi Redmi Note 12 Pro     Xiaomi   24762    79.0    True
# 13                        Vivo T1       Vivo   16990    80.0    True
# 14       Samsung Galaxy S23 Ultra    Samsung  114990    80.0    True
# 15                Apple iPhone 13      Apple   62999    79.0    True
# 16                       Vivo Y16       Vivo    9999    65.0   False
# 17           OPPO Reno 9 Pro Plus       OPPO   45999    86.0    True
# 18                    OnePlus 10R    OnePlus   32999    86.0    True
# 19                       Vivo Y22       Vivo   14499    72.0   False
#
#     has_ir_blaster       os        processor_name processor_brand num_of_core  \
# 0            False  android     Snapdragon 8 Gen2      Snapdragon   Octa Core
# 1            False  android        Snapdragon 695      Snapdragon   Octa Core
# 2            False  android           Exynos 1330          Exynos   Octa Core
# 3            False  android       Snapdragon  695      Snapdragon   Octa Core
# 4            False  android        Dimensity 1080       Dimensity   Octa Core
# 5            False  android      Snapdragon  750G      Snapdragon   Octa Core
# 6            False      ios            Bionic A15          Bionic   Hexa Core
# 7             True  android        Dimensity 1080       Dimensity   Octa Core
# 8            False      NaN  Snapdragon 778G Plus      Snapdragon   Octa Core
# 9            False      NaN       Dimensity  1300       Dimensity   Octa Core
# 10           False  android        Snapdragon 695      Snapdragon   Octa Core
# 11           False  android      Dimensity 700 5G       Dimensity   Octa Core
# 12            True      NaN        Dimensity 1080       Dimensity   Octa Core
# 13           False  android       Snapdragon  695      Snapdragon   Octa Core
# 14           False  android     Snapdragon 8 Gen2      Snapdragon   Octa Core
# 15           False      ios            Bionic A15          Bionic   Hexa Core
# 16           False  android             Helio P35           Helio   Octa Core
# 17           False      NaN    Snapdragon 8+ Gen1      Snapdragon   Octa Core
# 18           False      NaN    Dimensity 8100 Max       Dimensity   Octa Core
# 19           False  android             Helio G70           Helio   Octa Core
#
#     ram_capacity  storage_capacity  mah_capacity screen_size  \
# 0           12.0             256.0        5000.0         6.7
# 1           12.0             128.0        5000.0        6.59
# 2            6.0               4.0        5000.0         6.6
# 3           12.0             128.0        5000.0        6.55
# 4           12.0             128.0        5000.0         6.7
# 5           12.0             128.0        5000.0         6.6
# 6           12.0             128.0        3279.0         6.1
# 7            6.0             256.0        4980.0         6.6
# 8           12.0             128.0        4500.0        6.55
# 9           12.0             128.0        4500.0        6.43
# 10          12.0             128.0        5000.0         6.7
# 11          12.0             128.0        5000.0        6.56
# 12          12.0             128.0        5000.0         6.6
# 13          12.0             128.0        5000.0        6.58
# 14           6.0             256.0        5000.0         6.8
# 15          12.0             128.0        3240.0         6.1
# 16           3.0               2.0        5000.0        6.51
# 17           6.0             256.0        4700.0         6.7
# 18          12.0             128.0        5000.0         6.7
# 19           6.0               4.0        5000.0        6.55
#
#    screen_reosolution    rear_camera front_camera  memory_card_supported
# 0         1440 x 3216  50 + 48 + 32           16                   False
# 1         1080 x 2412    64 + 2 + 2           16                   False
# 2         1080 x 2408    50 + 2 + 2           13                    True
# 3         1080 x 2400    50 + 8 + 2           16                   False
# 4         1080 x 2412   108 + 8 + 2           16                   False
# 5         1080 x 2408    50 + 8 + 2            8                    True
# 6         1170 x 2532       12 + 12           12                   False
# 7         1080 x 2400   200 + 8 + 2           16                   False
# 8         1080 x 2400       50 + 50           16                   False
# 9         1080 x 2400    50 + 8 + 2           32                   False
# 10        1080 x 2400       108 + 2           16                    True
# 11         720 x 1612        50 + 2            8                    True
# 12        1080 x 2400    50 + 8 + 2           16                   False
# 13        1080 x 2408    50 + 2 + 2           16                   False
# 14        1440 x 3088           200           12                   False
# 15        1170 x 2532       12 + 12           12                   False
# 16         720 x 1600        13 + 2            5                    True
# 17        1080 x 2412    50 + 8 + 2           32                   False
# 18        1080 x 2412    50 + 8 + 2           16                   False
# 19         720 x 1612        50 + 2            8                    True

# %%
data.shape
# Out:
# (1020, 18)
